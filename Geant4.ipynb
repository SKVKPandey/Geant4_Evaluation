# %% [markdown]
# The given code has been done for experimenting with ideas related to Data Visualisation for Geant4 Project.

# %%
#connecting with drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#path declaration
path = "/content/drive/MyDrive/geant4.csv"

# %%
pip install squarify

# %%
#importing necessary libraries with alias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import squarify

# %%
geant4_df = pd.read_csv(path)

# %%
geant4_df
# Out:
#       comm                dso  \
# 0    g4run  libG4processes.so
# 1    g4run   libG4geometry.so
# 2    g4run  libG4processes.so
# 3    g4run              g4run
# 4    g4run   libG4tracking.so
# ..     ...                ...
# 182  g4run   libG4geometry.so
# 183  g4run       libm-2.28.so
# 184  g4run   libG4geometry.so
# 185  g4run   libG4geometry.so
# 186  g4run  libG4processes.so
#
#                                                 symbol        cycles  \
# 0             G4CrossSectionDataStore::GetCrossSection  918568148449
# 1                        G4PolyhedraSide::DistanceAway  737047916821
# 2                 G4GammaNuclearXS::GetIsoCrossSection  716211502127
# 3                      CMSMagneticField::GetFieldValue  658702825895
# 4          G4SteppingManager::DefinePhysicalStepLength  646199467676
# ..                                                 ...           ...
# 182  G4RKIntegrationDriver<G4TDormandPrince45<G4Mag...   35674152110
# ...

# %%
geant4_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   comm           187 non-null    object
#  1   dso            187 non-null    object
#  2   symbol         187 non-null    object
#  3   cycles         187 non-null    int64
#  4   instructions   187 non-null    int64
#  5   branches       187 non-null    int64
#  6   branch-misses  187 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 10.4+ KB

# %%
geant4_df.describe()
# Out:
#              cycles  instructions      branches  branch-misses
# count  1.870000e+02  1.870000e+02  1.870000e+02   1.870000e+02
# mean   1.492933e+11  2.274474e+11  3.507336e+10   4.395828e+08
# std    1.540755e+11  2.350474e+11  3.674628e+10   4.695295e+08
# min    3.436237e+10  6.516758e+09  1.352434e+09   6.050498e+06
# 25%    5.392508e+10  8.065833e+10  1.155746e+10   1.407652e+08
# 50%    8.122600e+10  1.267733e+11  1.854280e+10   2.462080e+08
# 75%    1.900224e+11  2.883097e+11  4.654018e+10   5.878254e+08
# max    9.185681e+11  1.342008e+12  2.149215e+11   2.635899e+09

# %% [markdown]
# Below is the Scatter Plot for Cycles vs Instructions. The color coding is according to the Libraries.

# %%
#sns.relplot('latitude', 'longitude', data=geant4_df, hue='room_type', style='neighbourhood_group')
sns.relplot('cycles', 'instructions', data=geant4_df, hue='dso', size='cycles')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Below shown figure is a trial attempt to make Treemap using Squarify and Pyplot.

# %%
plt.figure(figsize=(20,20))
squarify.plot(sizes=geant4_df.cycles, label=geant4_df.symbol, alpha=0.5)
plt.show()
